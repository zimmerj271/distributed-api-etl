# %% [markdown]
# # OAuth2 Client Credentials Demo
#
# This notebook demonstrates running the ETL pipeline against an API endpoint using OAuth2 Client Credentials Grant authentication via Keycloak.
#
# Unlike Password Grant, Client Credentials authenticates the application itself, not on behalf of a user. This is the recommended flow for service-to-service communication.
#
# ## Prerequisites
#
# Start Keycloak and the mock API service:
# ```bash
# make up-keycloak
# ```
#
# Services:
# - Keycloak Admin Console: `http://localhost:8180` (admin/admin)
# - Mock API: `http://mock-api:8000` (from Docker network)
#
# ## Client Credentials
#
# - Client ID: `etl-client`
# - Client Secret: `etl-client-secret`

# %%
import sys
from pathlib import Path

# %%
project_root = Path("/opt/spark/work")
src_path = project_root / "src"

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import sha2, expr
from pipeline.orchestrator import run_pipeline

# %%
spark = (
    SparkSession.builder
    .appName("oauth2_client_credentials_demo_pipeline")
    .getOrCreate()
)

# %% [markdown]
# ## Create Source DataFrame
#
# Generate a DataFrame with unique tracking IDs that will be used to make API requests.

# %%
df = (
    spark.range(50)
         .repartition(4)
         .select(
             sha2(expr("uuid()"), 256).alias("tracking_id")
         )
)
df.show(10)
# Out:
# +--------------------+
# |         tracking_id|
# +--------------------+
# |bc5859ab6df7abcd8...|
# |d4d4dedef53f77539...|
# |e35e52621abd9389c...|
# |2800fb0fe3e62b6c6...|
# |763e42509d65b3445...|
# |e3b8a35a4cef69268...|
# |8111a6a550703069d...|
# |4072b41a0d05b8d86...|
# |35781dcaeb0eb79b4...|
# |f903e9ffddf6d4bd4...|
# +--------------------+
# only showing top 10 rows

# %% [markdown]
# ## Run Pipeline
#
# Execute the ETL pipeline using the OAuth2 Client Credentials configuration.
#
# The pipeline will:
# 1. Authenticate with Keycloak using client credentials (no user involved)
# 2. Distribute the access token to all Spark executors
# 3. Make API requests with `Authorization: Bearer <token>` header
# 4. Automatically refresh tokens when they expire

# %%
config_path = project_root / "configs" / "examples" / "oauth2_client_credentials_demo.yml"

# %%
run_pipeline(
    spark=spark,
    config_path=config_path,
    source_df=df,
    source_id="tracking_id"
)
# Out:
# 2026-02-08 14:29:44,108 [INFO] [PipelineOrchestrator]: Starting driver-side authentication runtime service
# 2026-02-08 14:29:44,109 [INFO] [RpcBootstrapper]: Starting RPC token service...
# 2026-02-08 14:29:44,143 [INFO] AsyncBackgroundService[DriverTokenManager]: Background service started
# 2026-02-08 14:29:44,151 [INFO] AsyncBackgroundService[RpcService]: Background service started
# 2026-02-08 14:29:44,152 [INFO] [TokenRpcService]: Started at http://89d602eb842e:53007
# 2026-02-08 14:29:44,153 [INFO] [RpcBootstrapper]: TokenManager background refresh started.
# 2026-02-08 14:29:44,153 [INFO] [RpcBootstrapper]: RPC Token Service running at http://89d602eb842e:53007
# 2026-02-08 14:29:44,153 [INFO] [PipelineOrchestrator]: Adding authentication middleware
# 2026-02-08 14:29:44,153 [INFO] [PipelineOrchestrator]: ====== Executing Pipeline ======
# 2026-02-08 14:29:44,153 [INFO] [PipelineOrchestrator]: Request from URL: /http://mock-api:8000/api/oauth2/data
# 2026-02-08 14:29:44,154 [INFO] [TableManager]: Creating database demo
# 2026-02-08 14:29:44,680 [INFO] [DriverTokenManager]: Background token refresh loop started (margin=60s)
# 2026-02-08 14:29:49,452 [INFO] [TableManager]: Created Delta table: demo.oauth2_client_credentials_demo_response
# 2026-02-08 14:29:51,908 [INFO] [BatchProcessor]: ➤ Attempt 1: Processing 1 batches
# 2026-02-08 14:29:51,910 [INFO] [BatchProcessor]:     → Processing batch 1/1
# 2026-02-08 14:29:52,978 [INFO] numexpr.utils: Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2026-02-08 14:29:52,978 [INFO] numexpr.utils: NumExpr defaulting to 8 threads.
# 2026-02-08 14:29:54,044 [INFO] [TokenRpcService.request]: Worker 172.19.0.9 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000384 seconds
# 2026-02-08 14:29:54,049 [INFO] [TokenRpcService.request]: Worker 172.19.0.9 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000299 seconds
# 2026-02-08 14:29:54,053 [INFO] [TokenRpcService.request]: Worker 172.19.0.9 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000281 seconds
# 2026-02-08 14:29:54,069 [INFO] [TokenRpcService.request]: Worker 172.19.0.9 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000332 seconds
# 2026-02-08 14:29:54,145 [INFO] [TokenRpcService.request]: Worker 172.19.0.9 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000443 seconds
# ✓ All API requests processed
# 2026-02-08 14:29:56,192 [INFO] [RpcBootstrapper]: Stopping token refresh loop...
# 2026-02-08 14:29:56,193 [INFO] AsyncBackgroundService[DriverTokenManager]: Stopping...
# 2026-02-08 14:29:56,194 [INFO] [DriverTokenManager]: Background refresh loop cancelled
# 2026-02-08 14:29:56,195 [INFO] AsyncBackgroundService[DriverTokenManager]: Stopped
# 2026-02-08 14:29:56,195 [INFO] [RpcBootstrapper]: Stopping RPC network service...
# 2026-02-08 14:29:56,195 [INFO] AsyncBackgroundService[RpcService]: Stopping...
# 2026-02-08 14:29:56,196 [INFO] [TokenRpcService]: Cancel service received, cleaning up...
# 2026-02-08 14:29:56,196 [INFO] AsyncBackgroundService[RpcService]: Stopped
# 2026-02-08 14:29:56,197 [INFO] [RpcBootstrapper]: Shutdown complete.
# 2026-02-08 14:29:56,197 [INFO] [PipelineOrchestrator]: Pipeline run finished

# %% [markdown]
# ## Verify Results
#
# Read the sink table to verify the API responses were captured.

# %%
response_df = spark.table("demo.oauth2_client_credentials_demo_response")
response_df.show(10)
# Out:
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |          request_id|            row_hash|                 url|method|     request_headers|request_params|    request_metadata|status_code|    response_headers|           body_text|success|error_message|attempts|   response_metadata|       _request_time|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |4aa701e27bbf1d133...|316198866e9e1cd3f...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"66...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:48:...|
# |a23462e95d11bd8b3...|1b62798f7e70ee38a...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"02...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:48:...|
# |1d311eadfa054f4e9...|b138671c5738d57bd...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"a0...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:48:...|
# |aaf862edeaec5e520...|f31d51833d749c2f0...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"69...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:48:...|
# |2e50797c3a68dd029...|65cd7964e2991e1d6...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"00...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:48:...|
# |f358bc0570b9b87a3...|6d9e83f89930a06d0...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"eb...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:48:...|
# |a8ed90f560f458e78...|10aa894ec077936a3...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"20...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:48:...|
# |9e0a36420c7edd4f6...|ce17ed2aa4e18d101...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"04...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:48:...|
# |ecb03d470bcf6e8ae...|4fb9864c2e3312b4c...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"be...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:48:...|
# |72e45e2f134067e85...|0cf5986e7618e612d...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"6b...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:48:...|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# only showing top 10 rows

# %%
# Summary statistics
print(f"Total records: {response_df.count()}")
response_df.groupBy("status_code").count().show()
# Out:
# Total records: 50
# +-----------+-----+
# |status_code|count|
# +-----------+-----+
# |        200|   50|
# +-----------+-----+

# %%
# Sample response body - note the auth_method field shows "oauth2:bearer"
response_df.select("body_text").limit(3).show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |body_text                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{"request_id":"f106392b-6c3c-4e97-afb3-9f266adeecb6","timestamp":"2026-02-08T14:29:54.073281+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"20ed039c-1c5a-4646-82da-35169bc3569d","amount":70.36,"currency":"EUR","status":"pending","customer_id":"CUST-18582","product_code":"PRD-8541EABE","quantity":7,"region":"NA","priority":"medium","metadata":{"source":"mock-api","version":"1.0.0","random_value":"f053302ce4b13293"}}}   |
# |{"request_id":"c5afba04-2a30-40dc-89cc-8668b7952053","timestamp":"2026-02-08T14:29:54.077881+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"164712e3-9651-4d35-b4b7-79f5e1a401f5","amount":766.54,"currency":"EUR","status":"pending","customer_id":"CUST-94385","product_code":"PRD-33FD7791","quantity":52,"region":"EU","priority":"medium","metadata":{"source":"mock-api","version":"1.0.0","random_value":"e1d6b8616922ae2a"}}} |
# |{"request_id":"e87ef5d4-7f81-4989-91e1-c61bb6da8820","timestamp":"2026-02-08T14:29:54.084996+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"5320bf47-279e-433b-b802-97bd05ff7735","amount":428.28,"currency":"JPY","status":"processing","customer_id":"CUST-71027","product_code":"PRD-13004B0D","quantity":54,"region":"NA","priority":"high","metadata":{"source":"mock-api","version":"1.0.0","random_value":"abc85b340fd98108"}}}|
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 49074)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 755, in __init__
#     self.handle()
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 295, in handle
#     poll(accum_updates)
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 267, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 271, in accum_updates
#     num_updates = read_int(self.rfile)
#                   ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/spark/python/pyspark/serializers.py", line 596, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------
