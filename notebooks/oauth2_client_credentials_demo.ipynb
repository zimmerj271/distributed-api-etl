# %% [markdown]
# # OAuth2 Client Credentials Demo
#
# This notebook demonstrates running the ETL pipeline against an API endpoint using OAuth2 Client Credentials Grant authentication via Keycloak.
#
# Unlike Password Grant, Client Credentials authenticates the application itself, not on behalf of a user. This is the recommended flow for service-to-service communication.
#
# ## Prerequisites
#
# Start Keycloak and the mock API service:
# ```bash
# make up-keycloak
# ```
#
# Services:
# - Keycloak Admin Console: `http://localhost:8180` (admin/admin)
# - Mock API: `http://mock-api:8000` (from Docker network)
#
# ## Client Credentials
#
# - Client ID: `etl-client`
# - Client Secret: `etl-client-secret`

# %%
import sys
from pathlib import Path

# %%
# project_root = Path("/opt/spark/work")
project_root = Path("/opt/spark/app")
src_path = project_root / "src"

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import sha2, expr
from orchestration.orchestrator import run_pipeline

# %%
spark = (
    SparkSession.builder
    .appName("oauth2_client_credentials_demo_pipeline")
    .getOrCreate()
)

# %% [markdown]
# ## Create Source DataFrame
#
# Generate a DataFrame with unique tracking IDs that will be used to make API requests.

# %%
df = (
    spark.range(50)
         .repartition(4)
         .select(
             sha2(expr("uuid()"), 256).alias("tracking_id")
         )
)
df.show(10)
# Out:
# +--------------------+
# |         tracking_id|
# +--------------------+
# |e117f769a601bd247...|
# |410640310c211ab2b...|
# |91039f56b47cfe059...|
# |b79227527a1d8292a...|
# |bcdf25ec7c2151bc6...|
# |a8d99edbcfaff67ff...|
# |b027173f1a92de59d...|
# |ef0526890adcd8073...|
# |7779357563bc897a0...|
# |eaec91e7950433279...|
# +--------------------+
# only showing top 10 rows

# %% [markdown]
# ## Run Pipeline
#
# Execute the ETL pipeline using the OAuth2 Client Credentials configuration.
#
# The pipeline will:
# 1. Authenticate with Keycloak using client credentials (no user involved)
# 2. Distribute the access token to all Spark executors
# 3. Make API requests with `Authorization: Bearer <token>` header
# 4. Automatically refresh tokens when they expire

# %%
config_path = project_root / "configs" / "examples" / "oauth2_client_credentials_demo.yml"

# %%
run_pipeline(
    spark=spark,
    config_path=config_path,
    source_df=df,
    source_id="tracking_id"
)
# Out:
# 2026-02-19 14:15:46,571 [INFO] [PipelineOrchestrator]: Starting driver-side authentication runtime service
# 2026-02-19 14:15:46,572 [INFO] [RpcBootstrapper]: Starting RPC token service...
# 2026-02-19 14:15:46,598 [INFO] AsyncBackgroundService[DriverTokenManager]: Background service started
# 2026-02-19 14:15:46,614 [INFO] AsyncBackgroundService[RpcService]: Background service started
# 2026-02-19 14:15:46,615 [INFO] [TokenRpcService]: Started at http://5e7dfb25a9a4:57717
# 2026-02-19 14:15:46,615 [INFO] [RpcBootstrapper]: TokenManager background refresh started.
# 2026-02-19 14:15:46,616 [INFO] [RpcBootstrapper]: RPC Token Service running at http://5e7dfb25a9a4:57717
# 2026-02-19 14:15:46,616 [INFO] [PipelineOrchestrator]: Adding authentication middleware
# 2026-02-19 14:15:46,616 [INFO] [PipelineOrchestrator]: ====== Executing Pipeline ======
# 2026-02-19 14:15:46,616 [INFO] [PipelineOrchestrator]: Request from URL: /http://mock-api:8000/api/oauth2/data
# 2026-02-19 14:15:46,617 [INFO] [TableManager]: Creating database demo
# 2026-02-19 14:15:46,943 [INFO] [DriverTokenManager]: Background token refresh loop started (margin=60s)
# 2026-02-19 14:15:47,579 [WARNING] [TableManager]: Sink table OVERWRITE enabled. Table oauth2_client_credentials_demo_response will be replaced.
# 2026-02-19 14:15:54,773 [INFO] [TableManager]: Created Delta table: demo.oauth2_client_credentials_demo_response
# 2026-02-19 14:15:56,656 [INFO] [BatchProcessor]: ➤ Attempt 1: Processing 1 batches
# 2026-02-19 14:15:56,657 [INFO] [BatchProcessor]:     → Processing batch 1/1
# 2026-02-19 14:15:57,711 [INFO] numexpr.utils: Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2026-02-19 14:15:57,712 [INFO] numexpr.utils: NumExpr defaulting to 8 threads.
# 2026-02-19 14:15:58,748 [INFO] [TokenRpcService.request]: Worker 172.19.0.11 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000426 seconds
# 2026-02-19 14:15:58,761 [INFO] [TokenRpcService.request]: Worker 172.19.0.11 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000295 seconds
# 2026-02-19 14:15:58,771 [INFO] [TokenRpcService.request]: Worker 172.19.0.11 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000232 seconds
# 2026-02-19 14:15:58,795 [INFO] [TokenRpcService.request]: Worker 172.19.0.11 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000549 seconds
# 2026-02-19 14:15:58,834 [INFO] [TokenRpcService.request]: Worker 172.19.0.11 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.002358 seconds
# ✓ All API requests processed
# 2026-02-19 14:16:00,615 [INFO] [RpcBootstrapper]: Stopping token refresh loop...
# 2026-02-19 14:16:00,616 [INFO] AsyncBackgroundService[DriverTokenManager]: Stopping...
# 2026-02-19 14:16:00,617 [INFO] [DriverTokenManager]: Background refresh loop cancelled
# 2026-02-19 14:16:00,618 [INFO] AsyncBackgroundService[DriverTokenManager]: Stopped
# 2026-02-19 14:16:00,618 [INFO] [RpcBootstrapper]: Stopping RPC network service...
# 2026-02-19 14:16:00,618 [INFO] AsyncBackgroundService[RpcService]: Stopping...
# 2026-02-19 14:16:00,619 [INFO] [TokenRpcService]: Cancel service received, cleaning up...
# 2026-02-19 14:16:00,620 [INFO] AsyncBackgroundService[RpcService]: Stopped
# 2026-02-19 14:16:00,620 [INFO] [RpcBootstrapper]: Shutdown complete.
# 2026-02-19 14:16:00,620 [INFO] [PipelineOrchestrator]: Pipeline run finished

# %% [markdown]
# ## Verify Results
#
# Read the sink table to verify the API responses were captured.

# %%
response_df = spark.table("demo.oauth2_client_credentials_demo_response")
response_df.show(10)
# Out:
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |          request_id|            row_hash|                 url|method|     request_headers|request_params|    request_metadata|status_code|    response_headers|           body_text|success|error_message|attempts|   response_metadata|       _request_time|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |b79227527a1d8292a...|1ed7fc2d21679fbc1...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Thu, 19...|{"request_id":"eb...|   true|         NULL|       1|{"logs": ["-> GET...|2026-02-19 14:15:...|
# |e117f769a601bd247...|abb02c3d8056b2012...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Thu, 19...|{"request_id":"cb...|   true|         NULL|       1|{"logs": ["-> GET...|2026-02-19 14:15:...|
# |7779357563bc897a0...|5a27b5bf444bbb235...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Thu, 19...|{"request_id":"7d...|   true|         NULL|       1|{"logs": ["-> GET...|2026-02-19 14:15:...|
# |d13a849a08a33032b...|c7f6d737a36019d5b...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Thu, 19...|{"request_id":"07...|   true|         NULL|       1|{"logs": ["-> GET...|2026-02-19 14:15:...|
# |8c0b0f3073cfe8b0f...|fd66d15c57f8406e4...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Thu, 19...|{"request_id":"af...|   true|         NULL|       1|{"logs": ["-> GET...|2026-02-19 14:15:...|
# |9447d00dff9c70bb5...|bb4e89dd171d56cee...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Thu, 19...|{"request_id":"74...|   true|         NULL|       1|{"logs": ["-> GET...|2026-02-19 14:15:...|
# |4dcfec2758a4f07af...|ef6016fbf646bb88e...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Thu, 19...|{"request_id":"b4...|   true|         NULL|       1|{"logs": ["-> GET...|2026-02-19 14:15:...|
# |96ab361aa9dd1e795...|9b0e681dcb3692526...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Thu, 19...|{"request_id":"b2...|   true|         NULL|       1|{"logs": ["-> GET...|2026-02-19 14:15:...|
# |62bd88a490909d488...|9739fc15309258183...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Thu, 19...|{"request_id":"46...|   true|         NULL|       1|{"logs": ["-> GET...|2026-02-19 14:15:...|
# |08f52f3910460694c...|b912b7e3d9cd302bc...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Thu, 19...|{"request_id":"ed...|   true|         NULL|       1|{"logs": ["-> GET...|2026-02-19 14:15:...|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# only showing top 10 rows

# %%
# Summary statistics
print(f"Total records: {response_df.count()}")
response_df.groupBy("status_code").count().show()
# Out:
# Total records: 50
# +-----------+-----+
# |status_code|count|
# +-----------+-----+
# |        200|   50|
# +-----------+-----+

# %%
# Sample response body - note the auth_method field shows "oauth2:bearer"
response_df.select("body_text").limit(3).show(truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |body_text                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{"request_id":"eb00da81-7fb7-4edc-a0fe-6b3a35635175","timestamp":"2026-02-19T14:15:58.779946+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"9393512a-e9ef-4ba9-bb6a-36b000c7aaee","amount":377.01,"currency":"USD","status":"processing","customer_id":"CUST-30377","product_code":"PRD-40DD9B45","quantity":48,"region":"LATAM","priority":"medium","metadata":{"source":"mock-api","version":"1.0.0","random_value":"652037e0afcc658f"}}}|
# |{"request_id":"cbd2410e-5edc-4139-ba64-3ee974844e95","timestamp":"2026-02-19T14:15:58.778378+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"9901aaea-16cb-4cf0-8088-a542d1be4343","amount":998.81,"currency":"EUR","status":"processing","customer_id":"CUST-99094","product_code":"PRD-D826C8EA","quantity":41,"region":"LATAM","priority":"low","metadata":{"source":"mock-api","version":"1.0.0","random_value":"17d7e20ebe099591"}}}   |
# |{"request_id":"7d570bef-a54f-49fe-a11c-3f61b84b17e2","timestamp":"2026-02-19T14:15:58.782691+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"f1ddb4bd-c25f-4a39-aa97-40d0e48696d9","amount":402.61,"currency":"GBP","status":"failed","customer_id":"CUST-56179","product_code":"PRD-FC161671","quantity":16,"region":"APAC","priority":"low","metadata":{"source":"mock-api","version":"1.0.0","random_value":"d5408415281eeb61"}}}        |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
response_df.select("response_metadata").limit(1).collect()
# Out:
# [Row(response_metadata='{"logs": ["-> GET /http://mock-api:8000/api/oauth2/data", "[RetryMiddleware] Attempt 1/10 -> GET /http://mock-api:8000/api/oauth2/data", "<- 200 /http://mock-api:8000/api/oauth2/data"], "token_provider": {"provider": "RpcTokenProvider", "path": "rpc"}, "connection_warmup": {"warmed_up": false, "warmup_error": null, "warmup_timeout": 10}, "json": {"valid": true, "error": null}, "timing": {"total_seconds": 0.01}}')]
