# %% [markdown]
# # OAuth2 Client Credentials Demo
#
# This notebook demonstrates running the ETL pipeline against an API endpoint using OAuth2 Client Credentials Grant authentication via Keycloak.
#
# Unlike Password Grant, Client Credentials authenticates the application itself, not on behalf of a user. This is the recommended flow for service-to-service communication.
#
# ## Prerequisites
#
# Start Keycloak and the mock API service:
# ```bash
# make up-keycloak
# ```
#
# Services:
# - Keycloak Admin Console: `http://localhost:8180` (admin/admin)
# - Mock API: `http://mock-api:8000` (from Docker network)
#
# ## Client Credentials
#
# - Client ID: `etl-client`
# - Client Secret: `etl-client-secret`

# %%
import sys
from pathlib import Path

# %%
# project_root = Path("/opt/spark/work")
project_root = Path("/opt/spark/app")
src_path = project_root / "src"

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import sha2, expr
from pipeline.orchestrator import run_pipeline

# %%
spark = (
    SparkSession.builder
    .appName("oauth2_client_credentials_demo_pipeline")
    .getOrCreate()
)

# %% [markdown]
# ## Create Source DataFrame
#
# Generate a DataFrame with unique tracking IDs that will be used to make API requests.

# %%
df = (
    spark.range(50)
         .repartition(4)
         .select(
             sha2(expr("uuid()"), 256).alias("tracking_id")
         )
)
df.show(10)
# Out:
# +--------------------+
# |         tracking_id|
# +--------------------+
# |7c04fe275399d5510...|
# |c5127aadedecfc274...|
# |b67ad3b6f5ad1e554...|
# |7c3bb7899bb40a67f...|
# |d58efe410abb69d13...|
# |2f9bd00fb48a41f6c...|
# |f38364c88fc1dd8b9...|
# |5dbe37d4911423343...|
# |47203c709ac0bd857...|
# |7d956720afe7799ea...|
# +--------------------+
# only showing top 10 rows

# %% [markdown]
# ## Run Pipeline
#
# Execute the ETL pipeline using the OAuth2 Client Credentials configuration.
#
# The pipeline will:
# 1. Authenticate with Keycloak using client credentials (no user involved)
# 2. Distribute the access token to all Spark executors
# 3. Make API requests with `Authorization: Bearer <token>` header
# 4. Automatically refresh tokens when they expire

# %%
config_path = project_root / "configs" / "examples" / "oauth2_client_credentials_demo.yml"

# %%
run_pipeline(
    spark=spark,
    config_path=config_path,
    source_df=df,
    source_id="tracking_id"
)
# Out:
# 2026-02-10 14:01:54,561 [INFO] [PipelineOrchestrator]: Starting driver-side authentication runtime service
# 2026-02-10 14:01:54,562 [INFO] [RpcBootstrapper]: Starting RPC token service...
# 2026-02-10 14:01:54,597 [INFO] AsyncBackgroundService[DriverTokenManager]: Background service started
# 2026-02-10 14:01:54,608 [INFO] AsyncBackgroundService[RpcService]: Background service started
# 2026-02-10 14:01:54,609 [INFO] [TokenRpcService]: Started at http://3d452d1cc6a1:38383
# 2026-02-10 14:01:54,610 [INFO] [RpcBootstrapper]: TokenManager background refresh started.
# 2026-02-10 14:01:54,610 [INFO] [RpcBootstrapper]: RPC Token Service running at http://3d452d1cc6a1:38383
# 2026-02-10 14:01:54,610 [INFO] [PipelineOrchestrator]: Adding authentication middleware
# 2026-02-10 14:01:54,611 [INFO] [PipelineOrchestrator]: ====== Executing Pipeline ======
# 2026-02-10 14:01:54,611 [INFO] [PipelineOrchestrator]: Request from URL: /http://mock-api:8000/api/oauth2/data
# 2026-02-10 14:01:54,612 [INFO] [TableManager]: Creating database demo
# 2026-02-10 14:01:54,619 [INFO] [DriverTokenManager]: Background token refresh loop started (margin=60s)
# 2026-02-10 14:01:55,133 [WARNING] [TableManager]: Sink table OVERWRITE enabled. Table oauth2_client_credentials_demo_response will be replaced.
# 2026-02-10 14:02:01,497 [INFO] [TableManager]: Created Delta table: demo.oauth2_client_credentials_demo_response
# 2026-02-10 14:02:03,764 [INFO] [BatchProcessor]: ➤ Attempt 1: Processing 1 batches
# 2026-02-10 14:02:03,765 [INFO] [BatchProcessor]:     → Processing batch 1/1
# 2026-02-10 14:02:04,914 [INFO] numexpr.utils: Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2026-02-10 14:02:04,915 [INFO] numexpr.utils: NumExpr defaulting to 8 threads.
# 2026-02-10 14:02:05,953 [INFO] [TokenRpcService.request]: Worker 172.19.0.11 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000447 seconds
# 2026-02-10 14:02:05,975 [INFO] [TokenRpcService.request]: Worker 172.19.0.11 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000405 seconds
# 2026-02-10 14:02:05,981 [INFO] [TokenRpcService.request]: Worker 172.19.0.11 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.001004 seconds
# 2026-02-10 14:02:06,003 [INFO] [TokenRpcService.request]: Worker 172.19.0.11 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000847 seconds
# 2026-02-10 14:02:06,048 [INFO] [TokenRpcService.request]: Worker 172.19.0.11 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.001195 seconds
# ✓ All API requests processed
# 2026-02-10 14:02:07,975 [INFO] [RpcBootstrapper]: Stopping token refresh loop...
# 2026-02-10 14:02:07,975 [INFO] AsyncBackgroundService[DriverTokenManager]: Stopping...
# 2026-02-10 14:02:07,976 [INFO] [DriverTokenManager]: Background refresh loop cancelled
# 2026-02-10 14:02:07,977 [INFO] AsyncBackgroundService[DriverTokenManager]: Stopped
# 2026-02-10 14:02:07,978 [INFO] [RpcBootstrapper]: Stopping RPC network service...
# 2026-02-10 14:02:07,978 [INFO] AsyncBackgroundService[RpcService]: Stopping...
# 2026-02-10 14:02:07,979 [INFO] [TokenRpcService]: Cancel service received, cleaning up...
# 2026-02-10 14:02:07,981 [INFO] AsyncBackgroundService[RpcService]: Stopped
# 2026-02-10 14:02:07,981 [INFO] [RpcBootstrapper]: Shutdown complete.
# 2026-02-10 14:02:07,982 [INFO] [PipelineOrchestrator]: Pipeline run finished

# %% [markdown]
# ## Verify Results
#
# Read the sink table to verify the API responses were captured.

# %%
response_df = spark.table("demo.oauth2_client_credentials_demo_response")
response_df.show(10)
# Out:
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |          request_id|            row_hash|                 url|method|     request_headers|request_params|    request_metadata|status_code|    response_headers|           body_text|success|error_message|attempts|   response_metadata|       _request_time|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |2f9bd00fb48a41f6c...|4810533a8f1fa8309...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Tue, 10...|{"request_id":"c8...|   true|         NULL|       1|{"connection_warm...|2026-02-10 14:02:...|
# |7d956720afe7799ea...|22f25f4aaa78641ae...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Tue, 10...|{"request_id":"4e...|   true|         NULL|       1|{"connection_warm...|2026-02-10 14:02:...|
# |1c6de9c4a556ba5a2...|933c38ad458c0f0d0...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Tue, 10...|{"request_id":"3e...|   true|         NULL|       1|{"connection_warm...|2026-02-10 14:02:...|
# |eb1200b5fe94c1f6b...|c934a408f4407651e...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Tue, 10...|{"request_id":"27...|   true|         NULL|       1|{"connection_warm...|2026-02-10 14:02:...|
# |d860c85fbf3e38f8e...|fdaebcb62cca4147b...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Tue, 10...|{"request_id":"71...|   true|         NULL|       1|{"connection_warm...|2026-02-10 14:02:...|
# |227f1cc4927670806...|e6a1c1e6262cdcf7d...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Tue, 10...|{"request_id":"6d...|   true|         NULL|       1|{"connection_warm...|2026-02-10 14:02:...|
# |abdd4615ccea006b9...|a6d2ede58dfa84fe5...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Tue, 10...|{"request_id":"be...|   true|         NULL|       1|{"connection_warm...|2026-02-10 14:02:...|
# |814ac83910ad51bdb...|9fd796de621eb3bd0...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Tue, 10...|{"request_id":"0c...|   true|         NULL|       1|{"connection_warm...|2026-02-10 14:02:...|
# |6c86de1d4a439072e...|b97da7887f6348b34...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Tue, 10...|{"request_id":"c4...|   true|         NULL|       1|{"connection_warm...|2026-02-10 14:02:...|
# |b5f1d0aa2efaa3225...|48376fb51b50b03cb...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Tue, 10...|{"request_id":"d2...|   true|         NULL|       1|{"connection_warm...|2026-02-10 14:02:...|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# only showing top 10 rows

# %%
# Summary statistics
print(f"Total records: {response_df.count()}")
response_df.groupBy("status_code").count().show()
# Out:
# Total records: 50
# +-----------+-----+
# |status_code|count|
# +-----------+-----+
# |        200|   50|
# +-----------+-----+

# %%
# Sample response body - note the auth_method field shows "oauth2:bearer"
response_df.select("body_text").limit(3).show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |body_text                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{"request_id":"c88c77f0-a7a7-44a9-8292-010195162dbc","timestamp":"2026-02-10T14:02:06.005602+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"83c457c6-a50a-4b9f-922b-4ee1b96d7151","amount":365.96,"currency":"JPY","status":"failed","customer_id":"CUST-57976","product_code":"PRD-3272D1CB","quantity":66,"region":"LATAM","priority":"critical","metadata":{"source":"mock-api","version":"1.0.0","random_value":"af9c80ad9264f352"}}} |
# |{"request_id":"4ec1c50a-d3ab-4ef0-bf42-0ca0e107bdc8","timestamp":"2026-02-10T14:02:06.007145+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"b3e24bf0-a6c4-46be-bf61-603701ebd9d7","amount":844.4,"currency":"EUR","status":"failed","customer_id":"CUST-65094","product_code":"PRD-1271A101","quantity":37,"region":"APAC","priority":"medium","metadata":{"source":"mock-api","version":"1.0.0","random_value":"998748326c8c1723"}}}     |
# |{"request_id":"3e6aacb4-fcd6-429e-91b9-9a12ce641406","timestamp":"2026-02-10T14:02:06.009094+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"ca4aa1b0-cc0e-40a8-b9e4-f20539bc0e14","amount":679.96,"currency":"EUR","status":"completed","customer_id":"CUST-79005","product_code":"PRD-78F2630B","quantity":50,"region":"LATAM","priority":"medium","metadata":{"source":"mock-api","version":"1.0.0","random_value":"81c5d0f24f823b64"}}}|
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
