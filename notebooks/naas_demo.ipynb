# %%
import sys
from pathlib import Path

# %%
project_root = Path("/opt/spark/app")
src_path = project_root / "src"

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import sha2, expr
from orchestration.orchestrator import run_pipeline

# %%
spark = (
    SparkSession.builder
    .appName("naas_request_pipeline")
    .getOrCreate()
)

# %%
df = (
    spark.range(100)
         .repartition(4)
         .select(
             sha2(expr("uuid()"), 256).alias("tracking_id")
         )
)
df.show()
# Out:
# +--------------------+
# |         tracking_id|
# +--------------------+
# |abce912f920630981...|
# |78e11b8596a1f065c...|
# |68580b6422ac28049...|
# |4148448068adc97be...|
# |1bbe54924860975e4...|
# |15bd63aec360e920a...|
# |6ad76290cf25a377f...|
# |f663bb7219764f7a6...|
# |4a20accc645abd971...|
# |58762be6a92a0ce94...|
# |c9e9ad8be8e2e3410...|
# |0c7a5272594789e58...|
# |199ac9e89bc580376...|
# |3a4c968fe4de26000...|
# |10c3c08c97968d707...|
# |00eeafa9b31bcbacb...|
# |2f23d41399009e728...|
# |ffcbfda30cf543245...|
# |5b4febd2ffdef79b5...|
# |022863bc9336f8b66...|
# +--------------------+
# only showing top 20 rows

# %%
config_path = project_root / "configs" / "examples" / "naas_demo.yml"

# %%
run_pipeline(
    spark=spark,
    config_path=config_path,
    source_df=df,
    source_id="tracking_id"
)
# Out:
# 2026-02-06 00:07:13,434 [INFO] [PipelineOrchestrator]: Authentication does not have a runtime service... skipping
# 2026-02-06 00:07:13,435 [INFO] [PipelineOrchestrator]: ====== Executing Pipeline ======
# 2026-02-06 00:07:13,435 [INFO] [PipelineOrchestrator]: Request from URL: /https://naas.isalman.dev/no
# 2026-02-06 00:07:13,436 [INFO] [TableManager]: Creating database naas
# 2026-02-06 00:07:14,410 [WARNING] [TableManager]: Sink table OVERWRITE enabled. Table naas_api_response will be replaced.
# 2026-02-06 00:07:21,589 [INFO] [TableManager]: Created Delta table: naas.naas_api_response
# 2026-02-06 00:07:23,596 [INFO] [BatchProcessor]: ➤ Attempt 1: Processing 1 batches
# 2026-02-06 00:07:23,597 [INFO] [BatchProcessor]:     → Processing batch 1/1
# 2026-02-06 00:07:24,613 [INFO] numexpr.utils: Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2026-02-06 00:07:24,614 [INFO] numexpr.utils: NumExpr defaulting to 8 threads.
# ✓ All API requests processed
# 2026-02-06 00:07:37,849 [INFO] [PipelineOrchestrator]: Pipeline run finished

# %%
response_df = spark.table("naas.naas_api_response")
response_df.show()
# Out:
# +--------------------+--------------------+--------------------+------+--------------------+--------------+------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |          request_id|            row_hash|                 url|method|     request_headers|request_params|  request_metadata|status_code|    response_headers|           body_text|success|error_message|attempts|   response_metadata|       _request_time|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |78e11b8596a1f065c...|7f2e88c5cb3078682...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"Thank ...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |f663bb7219764f7a6...|f15899ca98053d918...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"As the...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |1e2114df151b5ba76...|e8a1cb36531508810...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"Agreei...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |199ac9e89bc580376...|7a6873f3e8b5014d2...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"I susp...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |68580b6422ac28049...|fc2cbf60f4e1c0c46...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"I'm pr...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |abce912f920630981...|7ee7580c5a84f2b6a...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"I can'...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |a3a15064d8c9b0d98...|d7b81b7d7fdaa7d05...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"I'm so...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |8b88ea7ee4e3011be...|2e7101e243d297c01...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"I'm co...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |4107522141e39b940...|d25b8eb8a1a28e74d...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"My spo...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |fc7a88706ba92b356...|e413ac5a7e6baeb34...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"I miss...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |23c394ad6f38e90ed...|3d812c0251799ee23...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"There’...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |348f92c63f5077b86...|0b88a5a272e6ce056...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"I'm in...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |1feacf7ea7ccee071...|5e047b81bf3ed2f22...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"If I s...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |02d1e16576d610da6...|7ba7c7d528a9d3b14...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"The sp...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |284d376a6406ef6b7...|0e45f559554780425...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"With a...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |4a53102851baad355...|b55e731d85ea049f4...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"I have...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |f6c567969c6ffb88d...|ee6aa886a1dc636f0...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"I'm on...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |cd37ccd903e39ded9...|26786e0b91aee7fa9...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"I alre...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |9aefc3d8eb659741a...|a1843c514e65d75b9...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"Astrol...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# |705ac0547641774a6...|2c9d747f4d3649bfe...|/https://naas.isa...|   GET|{"Accept": "appli...|            {}|{"vendor": "NaaS"}|        200|{"Date": "Fri, 06...|{"reason":"My dog...|   true|         NULL|       1|{"connection_warm...|2026-02-06 00:07:...|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# only showing top 20 rows

# %%
response_df.columns
# Out:
# ['request_id',
#  'row_hash',
#  'url',
#  'method',
#  'request_headers',
#  'request_params',
#  'request_metadata',
#  'status_code',
#  'response_headers',
#  'body_text',
#  'success',
#  'error_message',
#  'attempts',
#  'response_metadata',
#  '_request_time']

# %%
response_df.groupBy("status_code").count().show()
# Out:
# +-----------+-----+
# |status_code|count|
# +-----------+-----+
# |        200|  100|
# +-----------+-----+

# %%
response_df.select("body_text").limit(1).collect()
# Out:
# [Row(body_text='{"reason":"I\'ve been looking forward to reorganizing my button collection instead."}')]

# %%
response_df.select("response_metadata").limit(1).collect()
# Out:
# [Row(response_metadata='{"connection_warmup": {"warmed_up": false, "warmup_error": null, "warmup_timeout": 10}, "logs": ["-> GET /https://naas.isalman.dev/no", "[RetryMiddleware] Attempt 1/10 -> GET /https://naas.isalman.dev/no", "<- 200 /https://naas.isalman.dev/no"], "json": {"valid": true, "error": null}, "timing": {"total_seconds": 1.21}}')]
