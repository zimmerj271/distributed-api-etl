# %% [markdown]
# # Static Bearer Token Demo
#
# This notebook demonstrates running the ETL pipeline against an API endpoint that requires a static Bearer token.
#
# Unlike OAuth2, this uses a pre-configured token that doesn't expire or refresh. Useful for APIs that issue long-lived API keys.
#
# ## Prerequisites
#
# Start the mock API service:
# ```bash
# make up-keycloak
# ```
#
# The mock API will be available at `http://mock-api:8000` from within the Docker network.

# %%
import sys
from pathlib import Path

# %%
project_root = Path("/opt/spark/app")
src_path = project_root / "src"

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import sha2, expr
from pipeline.orchestrator import run_pipeline

# %%
spark = (
    SparkSession.builder
    .appName("bearer_token_demo_pipeline")
    .getOrCreate()
)

# %% [markdown]
# ## Create Source DataFrame
#
# Generate a DataFrame with unique tracking IDs that will be used to make API requests.

# %%
df = (
    spark.range(50)
         .repartition(4)
         .select(
             sha2(expr("uuid()"), 256).alias("tracking_id")
         )
)
df.show(10)
# Out:
# +--------------------+
# |         tracking_id|
# +--------------------+
# |9af5e2303f556b43b...|
# |00e79ecd2ebe66a26...|
# |f5f4c8a4d99492d15...|
# |4df5776d76b38feca...|
# |0abea37718048fbdf...|
# |14c3bdd21f162bd6c...|
# |79721e8d6965fd739...|
# |f9172d2c320644ded...|
# |1343d3ba08d8fab0d...|
# |daab7678ebf875123...|
# +--------------------+
# only showing top 10 rows

# %% [markdown]
# ## Run Pipeline
#
# Execute the ETL pipeline using the static bearer token configuration.
#
# The pipeline will automatically add the `Authorization: Bearer <token>` header to all requests.

# %%
config_path = project_root / "configs" / "examples" / "bearer_token_demo.yml"

# %%
run_pipeline(
    spark=spark,
    config_path=config_path,
    source_df=df,
    source_id="tracking_id"
)
# Out:
# 2026-02-08 14:14:41,866 [INFO] [PipelineOrchestrator]: Authentication does not have a runtime service... skipping
# 2026-02-08 14:14:41,867 [INFO] [PipelineOrchestrator]: Adding authentication middleware
# 2026-02-08 14:14:41,867 [INFO] [PipelineOrchestrator]: ====== Executing Pipeline ======
# 2026-02-08 14:14:41,867 [INFO] [PipelineOrchestrator]: Request from URL: /http://mock-api:8000/api/bearer/data
# 2026-02-08 14:14:41,868 [INFO] [TableManager]: Creating database demo
# 2026-02-08 14:14:46,907 [INFO] [TableManager]: Created Delta table: demo.bearer_token_demo_response
# 2026-02-08 14:14:49,189 [INFO] [BatchProcessor]: ➤ Attempt 1: Processing 1 batches
# 2026-02-08 14:14:49,190 [INFO] [BatchProcessor]:     → Processing batch 1/1
# 2026-02-08 14:14:50,250 [INFO] numexpr.utils: Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2026-02-08 14:14:50,251 [INFO] numexpr.utils: NumExpr defaulting to 8 threads.
# ✓ All API requests processed
# 2026-02-08 14:14:53,509 [INFO] [PipelineOrchestrator]: Pipeline run finished

# %% [markdown]
# ## Verify Results
#
# Read the sink table to verify the API responses were captured.

# %%
response_df = spark.table("demo.bearer_token_demo_response")
response_df.show(10)
# Out:
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |          request_id|            row_hash|                 url|method|     request_headers|request_params|    request_metadata|status_code|    response_headers|           body_text|success|error_message|attempts|   response_metadata|       _request_time|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |202c6673f2631e297...|32816f0de897d5c78...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"3c...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:44:...|
# |3580dcaf2142f7ca6...|6082cc0074493a009...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"08...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:44:...|
# |e47b4786bb6098960...|a6599a51548990579...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"48...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:44:...|
# |3fbaa63f28ea4adab...|9a6d87f49f5f5f808...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"4b...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:44:...|
# |467698cbbca991796...|8aa2697361f42ecf1...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"c0...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:44:...|
# |2350cdfb2445740e8...|ee3a0746c3f304dc3...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"58...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:44:...|
# |d706b388a505d3b60...|359fac5c0b6b8f115...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"59...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:44:...|
# |bbc9e49e8d8dd4227...|72b7b01af75c8ee98...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"39...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:44:...|
# |a8d394dad1ddcdf79...|8f292de72c3d98e93...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"3b...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:44:...|
# |e5568fbf6807dc13b...|3e76ce7c428785ad5...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"0a...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:44:...|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# only showing top 10 rows

# %%
# Summary statistics
print(f"Total records: {response_df.count()}")
response_df.groupBy("status_code").count().show()
# Out:
# Total records: 100
# +-----------+-----+
# |status_code|count|
# +-----------+-----+
# |        200|  100|
# +-----------+-----+

# %%
# Sample response body - note the auth_method field shows "bearer:static"
response_df.select("body_text").limit(3).show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |body_text                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{"request_id":"d76dc0c8-bdd0-48cc-a6ff-c3e0821e419d","timestamp":"2026-02-08T14:14:51.327326+00:00","auth_method":"bearer:static","data":{"transaction_id":"b8532db1-4383-46f4-ab40-a416072dea55","amount":272.83,"currency":"EUR","status":"processing","customer_id":"CUST-37960","product_code":"PRD-FCE1E67E","quantity":61,"region":"LATAM","priority":"critical","metadata":{"source":"mock-api","version":"1.0.0","random_value":"bf9903eec6610e32"}}}|
# |{"request_id":"9acb0f08-0da5-41ff-b5bb-f6474cdfdb10","timestamp":"2026-02-08T14:14:51.330348+00:00","auth_method":"bearer:static","data":{"transaction_id":"a36d09cf-6ef6-46ff-8032-37a08569ff52","amount":900.82,"currency":"USD","status":"pending","customer_id":"CUST-66990","product_code":"PRD-9F330696","quantity":50,"region":"LATAM","priority":"high","metadata":{"source":"mock-api","version":"1.0.0","random_value":"4b779a997e39e9ce"}}}       |
# |{"request_id":"c8f6f98e-8d24-4356-bed2-c6bd67594f78","timestamp":"2026-02-08T14:14:51.331903+00:00","auth_method":"bearer:static","data":{"transaction_id":"60c3fc6e-423d-4b85-b462-f69885c3f996","amount":482.73,"currency":"USD","status":"completed","customer_id":"CUST-03459","product_code":"PRD-6B69887E","quantity":74,"region":"APAC","priority":"low","metadata":{"source":"mock-api","version":"1.0.0","random_value":"82d89ec081026331"}}}       |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 46182)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 755, in __init__
#     self.handle()
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 295, in handle
#     poll(accum_updates)
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 267, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 271, in accum_updates
#     num_updates = read_int(self.rfile)
#                   ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/spark/python/pyspark/serializers.py", line 596, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------
