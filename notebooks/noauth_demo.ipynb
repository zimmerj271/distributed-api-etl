# %% [markdown]
# # No Authentication Demo
#
# This notebook demonstrates running the ETL pipeline against an API endpoint that requires no authentication.
#
# ## Prerequisites
#
# Start the mock API service:
# ```bash
# make up-keycloak
# ```
#
# The mock API will be available at `http://mock-api:8000` from within the Docker network.

# %%
import sys
from pathlib import Path

# %%
project_root = Path("/opt/spark/work")
src_path = project_root / "src"

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import sha2, expr
from pipeline.orchestrator import run_pipeline

# %%
spark = (
    SparkSession.builder
    .appName("noauth_demo_pipeline")
    .getOrCreate()
)

# %% [markdown]
# ## Create Source DataFrame
#
# Generate a DataFrame with unique tracking IDs that will be used to make API requests.

# %%
df = (
    spark.range(50)
         .repartition(4)
         .select(
             sha2(expr("uuid()"), 256).alias("tracking_id")
         )
)
df.show(10)
# Out:
# +--------------------+
# |         tracking_id|
# +--------------------+
# |dc78aee4cb79e2e57...|
# |ef56312324d7ff41d...|
# |d47b2ca42cea5a982...|
# |63fa18bebf8bf609f...|
# |b30b10f17a5071965...|
# |10615b5277b4e0f52...|
# |b9b75d978e97f21d5...|
# |5367c80ad617e4fba...|
# |1ed8837d97e899882...|
# |f01fc087545fa5c27...|
# +--------------------+
# only showing top 10 rows

# %% [markdown]
# ## Run Pipeline
#
# Execute the ETL pipeline using the no-auth configuration.

# %%
config_path = project_root / "configs" / "examples" / "noauth_demo.yml"

# %%
run_pipeline(
    spark=spark,
    config_path=config_path,
    source_df=df,
    source_id="tracking_id"
)
# Out:
# 2026-02-08 14:15:57,669 [INFO] [PipelineOrchestrator]: Authentication does not have a runtime service... skipping
# 2026-02-08 14:15:57,670 [INFO] [PipelineOrchestrator]: ====== Executing Pipeline ======
# 2026-02-08 14:15:57,670 [INFO] [PipelineOrchestrator]: Request from URL: /http://mock-api:8000/api/noauth/data
# 2026-02-08 14:15:57,671 [INFO] [TableManager]: Creating database demo
# 2026-02-08 14:16:03,248 [INFO] [TableManager]: Created Delta table: demo.noauth_demo_response
# 2026-02-08 14:16:05,836 [INFO] [BatchProcessor]: ➤ Attempt 1: Processing 1 batches
# 2026-02-08 14:16:05,837 [INFO] [BatchProcessor]:     → Processing batch 1/1
# 2026-02-08 14:16:06,851 [INFO] numexpr.utils: Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2026-02-08 14:16:06,851 [INFO] numexpr.utils: NumExpr defaulting to 8 threads.
# ✓ All API requests processed
# 2026-02-08 14:16:10,106 [INFO] [PipelineOrchestrator]: Pipeline run finished

# %% [markdown]
# ## Verify Results
#
# Read the sink table to verify the API responses were captured.

# %%
response_df = spark.table("demo.noauth_demo_response")
response_df.show(10)
# Out:
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |          request_id|            row_hash|                 url|method|     request_headers|request_params|    request_metadata|status_code|    response_headers|           body_text|success|error_message|attempts|   response_metadata|       _request_time|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |aca33682944ffc0ae...|0322fd9df26a4a55e...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"87...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:46:...|
# |e6a8b973f0bd71b70...|b3f33b17ab9f743d2...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"0b...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:46:...|
# |9739d97bc1a4a2a89...|f3b1dfbafa17b0662...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"9a...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:46:...|
# |106c78dfb5b3a543d...|00885fa13bdd1c197...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"a0...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:46:...|
# |9fba367a0e9914c57...|5f937bf1c26bf43d3...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"86...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:46:...|
# |1ebc2c2b90602b868...|b4fdb5be3068f70c2...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"13...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:46:...|
# |416dca0bcb5aae871...|2adf344cc6dc4fedb...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"73...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:46:...|
# |efb20d9efa8e054cc...|80fb912137323abef...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"44...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:46:...|
# |5683be697498c4884...|f593179b5f68bb7f0...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"e9...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:46:...|
# |c28f9aedd2ca33e2c...|53399e93873919605...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"78...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:46:...|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# only showing top 10 rows

# %%
# Summary statistics
print(f"Total records: {response_df.count()}")
response_df.groupBy("status_code").count().show()
# Out:
# Total records: 100
# +-----------+-----+
# |status_code|count|
# +-----------+-----+
# |        200|  100|
# +-----------+-----+

# %%
# Sample response body
response_df.select("body_text").limit(3).show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |body_text                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{"request_id":"c92e008a-d208-498b-aa9b-c9c88d938ab5","timestamp":"2026-02-08T14:16:07.915097+00:00","auth_method":"none","data":{"transaction_id":"49a951fd-e973-4b9a-a744-ad3c5893de27","amount":105.32,"currency":"JPY","status":"pending","customer_id":"CUST-75648","product_code":"PRD-A49A1C46","quantity":69,"region":"EU","priority":"medium","metadata":{"source":"mock-api","version":"1.0.0","random_value":"b7d3706ef6cb48b4"}}}  |
# |{"request_id":"593f8c42-6e92-403f-967f-ca15176b042f","timestamp":"2026-02-08T14:16:07.917293+00:00","auth_method":"none","data":{"transaction_id":"18142cdb-dabc-4f59-871f-09b55b9ca5f0","amount":391.87,"currency":"JPY","status":"failed","customer_id":"CUST-63544","product_code":"PRD-190234BB","quantity":84,"region":"EU","priority":"medium","metadata":{"source":"mock-api","version":"1.0.0","random_value":"83c1e6bac02637c7"}}}   |
# |{"request_id":"0c959aa3-6911-473f-ab8e-9e7aa48d5a9c","timestamp":"2026-02-08T14:16:07.918862+00:00","auth_method":"none","data":{"transaction_id":"f44684ae-f6d8-43ee-931c-708130da0412","amount":207.88,"currency":"GBP","status":"processing","customer_id":"CUST-31844","product_code":"PRD-8BD65628","quantity":11,"region":"APAC","priority":"low","metadata":{"source":"mock-api","version":"1.0.0","random_value":"63ebc1d5ee98eb31"}}}|
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 39368)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 755, in __init__
#     self.handle()
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 295, in handle
#     poll(accum_updates)
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 267, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 271, in accum_updates
#     num_updates = read_int(self.rfile)
#                   ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/spark/python/pyspark/serializers.py", line 596, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------
