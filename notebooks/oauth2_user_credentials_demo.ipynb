# %% [markdown]
# # OAuth2 Password Grant Demo
#
# This notebook demonstrates running the ETL pipeline against an API endpoint using OAuth2 Password Grant (Resource Owner Password Credentials) authentication via Keycloak.
#
# ## Prerequisites
#
# Start Keycloak and the mock API service:
# ```bash
# make up-keycloak
# ```
#
# Services:
# - Keycloak Admin Console: `http://localhost:8180` (admin/admin)
# - Mock API: `http://mock-api:8000` (from Docker network)
#
# ## OAuth2 Flow
#
# 1. The driver obtains an access token from Keycloak using user credentials
# 2. Tokens are distributed to executors via RPC
# 3. Executors use the token for API requests
# 4. Token refresh is handled automatically

# %%
import sys
from pathlib import Path

# %%
project_root = Path("/opt/spark/work")
src_path = project_root / "src"

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import sha2, expr
from pipeline.orchestrator import run_pipeline

# %%
spark = (
    SparkSession.builder
    .appName("oauth2_password_demo_pipeline")
    .getOrCreate()
)

# %% [markdown]
# ## Create Source DataFrame
#
# Generate a DataFrame with unique tracking IDs that will be used to make API requests.

# %%
df = (
    spark.range(50)
         .repartition(4)
         .select(
             sha2(expr("uuid()"), 256).alias("tracking_id")
         )
)
df.show(10)
# Out:
# +--------------------+
# |         tracking_id|
# +--------------------+
# |ded0a3107c8334a60...|
# |df8f72dfd0a8bffed...|
# |161b445ce7a24ecf0...|
# |af26666ea13b9ae78...|
# |848f7615a10ff69b5...|
# |9a6a8fd2f978e41bd...|
# |a5ae76985a21cf042...|
# |44028bdf3812d002e...|
# |81bd4bc0dff1e13ff...|
# |479353dfdaad52fd1...|
# +--------------------+
# only showing top 10 rows

# %% [markdown]
# ## Run Pipeline
#
# Execute the ETL pipeline using the OAuth2 Password Grant configuration.
#
# The pipeline will:
# 1. Authenticate with Keycloak using user credentials
# 2. Distribute the access token to all Spark executors
# 3. Make API requests with `Authorization: Bearer <token>` header
# 4. Automatically refresh tokens when they expire

# %%
config_path = project_root / "configs" / "examples" / "oauth2_keycloak_demo.yml"

# %%
run_pipeline(
    spark=spark,
    config_path=config_path,
    source_df=df,
    source_id="tracking_id"
)
# Out:
# 2026-02-08 14:30:30,818 [INFO] [PipelineOrchestrator]: Starting driver-side authentication runtime service
# 2026-02-08 14:30:30,819 [INFO] [RpcBootstrapper]: Starting RPC token service...
# 2026-02-08 14:30:30,836 [INFO] AsyncBackgroundService[DriverTokenManager]: Background service started
# 2026-02-08 14:30:30,839 [INFO] AsyncBackgroundService[RpcService]: Background service started
# 2026-02-08 14:30:30,841 [INFO] [TokenRpcService]: Started at http://89d602eb842e:36275
# 2026-02-08 14:30:30,843 [INFO] [RpcBootstrapper]: TokenManager background refresh started.
# 2026-02-08 14:30:30,843 [INFO] [RpcBootstrapper]: RPC Token Service running at http://89d602eb842e:36275
# 2026-02-08 14:30:30,843 [INFO] [PipelineOrchestrator]: Adding authentication middleware
# 2026-02-08 14:30:30,844 [INFO] [PipelineOrchestrator]: ====== Executing Pipeline ======
# 2026-02-08 14:30:30,844 [INFO] [PipelineOrchestrator]: Request from URL: /http://mock-api:8000/api/oauth2/data
# 2026-02-08 14:30:30,844 [INFO] [TableManager]: Creating database demo
# 2026-02-08 14:30:31,244 [INFO] [DriverTokenManager]: Background token refresh loop started (margin=60s)
# 2026-02-08 14:30:36,128 [INFO] [TableManager]: Created Delta table: demo.oauth2_demo_response
# 2026-02-08 14:30:38,436 [INFO] [BatchProcessor]: ➤ Attempt 1: Processing 1 batches
# 2026-02-08 14:30:38,437 [INFO] [BatchProcessor]:     → Processing batch 1/1
# 2026-02-08 14:30:39,421 [INFO] numexpr.utils: Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2026-02-08 14:30:39,421 [INFO] numexpr.utils: NumExpr defaulting to 8 threads.
# 2026-02-08 14:30:40,556 [INFO] [TokenRpcService.request]: Worker 172.19.0.9 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.001006 seconds
# 2026-02-08 14:30:40,567 [INFO] [TokenRpcService.request]: Worker 172.19.0.9 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000285 seconds
# 2026-02-08 14:30:40,590 [INFO] [TokenRpcService.request]: Worker 172.19.0.9 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000758 seconds
# 2026-02-08 14:30:40,612 [INFO] [TokenRpcService.request]: Worker 172.19.0.9 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000488 seconds
# 2026-02-08 14:30:40,641 [INFO] [TokenRpcService.request]: Worker 172.19.0.9 → GET /token HTTP/1.1 | Status: 200 | Duration: 0.000424 seconds
# ✓ All API requests processed
# 2026-02-08 14:30:42,730 [INFO] [RpcBootstrapper]: Stopping token refresh loop...
# 2026-02-08 14:30:42,730 [INFO] AsyncBackgroundService[DriverTokenManager]: Stopping...
# 2026-02-08 14:30:42,731 [INFO] [DriverTokenManager]: Background refresh loop cancelled
# 2026-02-08 14:30:42,731 [INFO] AsyncBackgroundService[DriverTokenManager]: Stopped
# 2026-02-08 14:30:42,732 [INFO] [RpcBootstrapper]: Stopping RPC network service...
# 2026-02-08 14:30:42,732 [INFO] AsyncBackgroundService[RpcService]: Stopping...
# 2026-02-08 14:30:42,733 [INFO] [TokenRpcService]: Cancel service received, cleaning up...
# 2026-02-08 14:30:42,734 [INFO] AsyncBackgroundService[RpcService]: Stopped
# 2026-02-08 14:30:42,735 [INFO] [RpcBootstrapper]: Shutdown complete.
# 2026-02-08 14:30:42,735 [INFO] [PipelineOrchestrator]: Pipeline run finished

# %% [markdown]
# ## Verify Results
#
# Read the sink table to verify the API responses were captured.

# %%
response_df = spark.table("demo.oauth2_user_credentials_demo_response")
response_df.show(10)
# Out:
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |          request_id|            row_hash|                 url|method|     request_headers|request_params|    request_metadata|status_code|    response_headers|           body_text|success|error_message|attempts|   response_metadata|       _request_time|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# |e6caee7b79a3b1dc1...|75372c37a418ab529...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"1b...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:54:...|
# |c89227a14ee65a2a8...|e590f663c79f56b7d...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"ba...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:54:...|
# |47ba070a6864375de...|92a7314903eaeb1cd...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"dc...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:54:...|
# |9c93d2da43e071091...|30410eae9ef5f8a7a...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"11...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:54:...|
# |ef1f4ec100f5d0620...|50c5a26eb371d3343...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"71...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:54:...|
# |47a3eecb0b04ab9ae...|8cf19fbe00ce204f9...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"00...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:54:...|
# |63a2bad9cc5e5c013...|d3f510789599a3b7c...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"8d...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:54:...|
# |d561c1c3d2fc9f272...|b06c81d7e0e829b03...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"c6...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:54:...|
# |0e925e819c597fd81...|b8b5374ebc1631949...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"3e...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:54:...|
# |5750e78083e457300...|b1e27cdb0ce385e68...|/http://mock-api:...|   GET|{"Accept": "appli...|            {}|{"vendor": "mock-...|        200|{"Date": "Mon, 09...|{"request_id":"af...|   true|         NULL|       1|{"connection_warm...|2026-02-09 23:54:...|
# +--------------------+--------------------+--------------------+------+--------------------+--------------+--------------------+-----------+--------------------+--------------------+-------+-------------+--------+--------------------+--------------------+
# only showing top 10 rows

# %%
# Summary statistics
print(f"Total records: {response_df.count()}")
response_df.groupBy("status_code").count().show()
# Out:
# Total records: 50
# +-----------+-----+
# |status_code|count|
# +-----------+-----+
# |        200|   50|
# +-----------+-----+

# %%
# Sample response body - note the auth_method field shows "oauth2:bearer"
response_df.select("body_text").limit(3).show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |body_text                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{"request_id":"7aae6845-9b30-4751-972a-cec8dd3c5097","timestamp":"2026-02-08T14:30:40.618133+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"67f2e141-dc18-4265-aa76-4bb8f42cdb97","amount":828.26,"currency":"USD","status":"pending","customer_id":"CUST-76551","product_code":"PRD-691760A6","quantity":84,"region":"APAC","priority":"medium","metadata":{"source":"mock-api","version":"1.0.0","random_value":"abcff0c7dfd52e91"}}}   |
# |{"request_id":"b6046317-d610-460a-b2be-dea010fa8dab","timestamp":"2026-02-08T14:30:40.620065+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"12da79bb-2a44-4638-8791-d1194d5196be","amount":437.62,"currency":"GBP","status":"completed","customer_id":"CUST-02606","product_code":"PRD-6AAFACE3","quantity":23,"region":"NA","priority":"medium","metadata":{"source":"mock-api","version":"1.0.0","random_value":"848f381346f6c789"}}}   |
# |{"request_id":"0dd55b90-35c3-4126-9dc0-6448e81937be","timestamp":"2026-02-08T14:30:40.622137+00:00","auth_method":"oauth2:bearer","data":{"transaction_id":"9decf2a2-e16d-415e-877b-cd746fcf1cf3","amount":751.8,"currency":"USD","status":"processing","customer_id":"CUST-12476","product_code":"PRD-BC60CF20","quantity":100,"region":"NA","priority":"critical","metadata":{"source":"mock-api","version":"1.0.0","random_value":"4acef6dcdc58f5ad"}}}|
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 36668)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/opt/conda/lib/python3.11/socketserver.py", line 755, in __init__
#     self.handle()
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 295, in handle
#     poll(accum_updates)
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 267, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/usr/local/spark/python/pyspark/accumulators.py", line 271, in accum_updates
#     num_updates = read_int(self.rfile)
#                   ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/spark/python/pyspark/serializers.py", line 596, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------
